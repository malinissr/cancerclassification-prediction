# %% [markdown]
# <a href="https://colab.research.google.com/github/malinissr/cancerclassification-prediction/blob/main/Cancer_classification_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
data=pd.read_csv('cancer_data.csv')
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.drop('id',axis=1,inplace=True)
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
data.shape
# Out:
# (569, 32)

# %%
data.isna().sum()
# Out:
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# ...

# %%
data.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
data['diagnosis']=data['diagnosis'].map({'M':1,'B':0})

# %%
data.to_csv('clean-data.csv')
data.diagnosis.unique()
# Out:
# array([1, 0])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize']=(14,7)
plt.rcParams['axes.titlesize']='large'
data=pd.read_csv('clean-data.csv',index_col=False)
print(data)
# Out:
#      Unnamed: 0  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0             0          1        17.99         10.38          122.80
# 1             1          1        20.57         17.77          132.90
# 2             2          1        19.69         21.25          130.00
# 3             3          1        11.42         20.38           77.58
# 4             4          1        20.29         14.34          135.10
# ..          ...        ...          ...           ...             ...
# 564         564          1        21.56         22.39          142.00
# 565         565          1        20.13         28.25          131.20
# 566         566          1        16.60         28.08          108.30
# 567         567          1        20.60         29.33          140.10
# 568         568          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %%
data.drop('Unnamed: 0',axis=1, inplace=True)
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
data.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
diag_gr=data['diagnosis'].value_counts()
diag_gr
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
array = data.values
#2dimensional array[row,column]
X = array[:,1:31]
y = array[:,0]
new_array=y.astype('i')

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
Xs=scaler.fit_transform(X)

# %% [markdown]
# Training the model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=7)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((398, 30), (398,), (171, 30), (171,))

# %% [markdown]
# Principal Component Analysis

# %%
from sklearn.decomposition import PCA
n_components=20
pca=PCA(n_components=n_components)
pca.fit(X_train)
pc_train=pd.DataFrame(pca.transform(X_train),columns=['PC'+str(i+1)for i in range(n_components)])
pc_test=pd.DataFrame(pca.transform(X_test),columns=['PC'+str(i+1)for i in range(n_components)])
pca.explained_variance_ratio_
explained_variance=pca.explained_variance_ratio_
explained_variance
# Out:
# array([9.81516260e-01, 1.65989019e-02, 1.68776788e-03, 1.09782828e-04,
#        7.58724232e-05, 6.15210646e-06, 3.91009050e-06, 7.64424828e-07,
#        3.48944639e-07, 1.38756904e-07, 6.79838812e-08, 1.49656544e-08,
#        7.20893208e-09, 4.34934899e-09, 2.77021829e-09, 1.43057225e-09,
#        7.32742168e-10, 4.59453940e-10, 3.61975439e-10, 3.11655724e-10])

# %% [markdown]
# K-Nearest Neighbor Model

# %%
from sklearn.metrics import classification_report,ConfusionMatrixDisplay,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(X_train, y_train)
prediction = knn.predict(X_test)
accuracy = accuracy_score(y_test, prediction)
print("The accuracy of K-Nearest Neighbor model:",accuracy*100)
print(classification_report(y_test,prediction))
# Out:
# The accuracy of K-Nearest Neighbor model: 94.73684210526315
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.96       116
#          1.0       0.93      0.91      0.92        55
#
#     accuracy                           0.95       171
#    macro avg       0.94      0.94      0.94       171
# weighted avg       0.95      0.95      0.95       171

# %% [markdown]
# PCA with KNN model

# %%
pca_model=KNeighborsClassifier(n_neighbors=5)
pca_model.fit(pc_train,y_train)
pca_prediction1=pca_model.predict(pc_test)
pca_accuracy1=accuracy_score(y_test,pca_prediction1)
print("The accuracy on PCA KNearestNeighbor model:",pca_accuracy1*100)
# Out:
# The accuracy on PCA KNearestNeighbor model: 94.73684210526315

# %% [markdown]
# CONFUSION MATRIX

# %%
matrix=confusion_matrix(y_test,prediction)
display=ConfusionMatrixDisplay(confusion_matrix=matrix,display_labels=['Benign','Malignant'])
display.plot(cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# BAR CHART

# %%
sns.set_style("white")
sns.set_context({"figure.figsize":(6,4)})
sns.countplot(x=data['diagnosis'],hue=data['diagnosis'],label='Count',palette="RdPu",legend=False)
plt.show()

# %% [markdown]
# PIE CHART

# %%
plt.figure(figsize=(7,5))
sns.set_style("whitegrid")
plt.pie(data['diagnosis'].value_counts(),autopct='%1.2f%%', startangle=90)
plt.axis('equal')
plt.title("Benign & Malignant")
plt.show()

# %% [markdown]
# Support vector Machine Model

# %%
from sklearn import svm
support_vector=svm.SVC(kernel='linear',gamma=0.1,C=0.1)
support_vector.fit(X_train,y_train)
prediction2=support_vector.predict(X_test)
accuracy2=accuracy_score(y_test,prediction2)
print("The Accuracy of SVM:",accuracy2*100)
print(classification_report(y_test,prediction2))
# Out:
# The Accuracy of SVM: 95.32163742690058
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.99      0.97       116
#          1.0       0.98      0.87      0.92        55
#
#     accuracy                           0.95       171
#    macro avg       0.96      0.93      0.94       171
# weighted avg       0.95      0.95      0.95       171

# %% [markdown]
# PCA with Support Vector Machine model

# %%
pca_model=svm.SVC(kernel='linear',gamma=0.1,C=0.1)
pca_model.fit(pc_train,y_train)
pca_prediction2=pca_model.predict(pc_test)
pca_accuracy2=accuracy_score(y_test,pca_prediction2)
print("The accuracy on PCA SVM model:",pca_accuracy2*100)
# Out:
# The accuracy on PCA SVM model: 95.32163742690058

# %% [markdown]
# Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(max_iter=30000)
lr.fit(X_train,y_train)
prediction1=lr.predict(X_test)
accuracy1=accuracy_score(y_test,prediction1)
print("The accuracy of LogisticRegression model:",accuracy1*100)
print(classification_report(y_test,prediction1))
# Out:
# The accuracy of LogisticRegression model: 95.90643274853801
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97       116
#          1.0       0.98      0.89      0.93        55
#
#     accuracy                           0.96       171
#    macro avg       0.97      0.94      0.95       171
# weighted avg       0.96      0.96      0.96       171

# %% [markdown]
# PCA on Logistic Regression Model

# %%
pca_model=LogisticRegression(max_iter=30000)
pca_model.fit(pc_train,y_train)
pca_prediction3=pca_model.predict(pc_test)
pca_accuracy3=accuracy_score(y_test,pca_prediction3)
print("The accuracy on PCA LogisticRegression model:",pca_accuracy3*100)
# Out:
# The accuracy on PCA LogisticRegression model: 95.90643274853801

# %% [markdown]
# Naive Bayes Model

# %%
from sklearn.naive_bayes import GaussianNB
NB = GaussianNB()
NB.fit(X_train, y_train)
prediction4=NB.predict(X_test)
accuracy4 = accuracy_score(y_test, prediction4)
print("The accuracy of NaiveBayes model:",accuracy4*100)
print(classification_report(y_test, prediction4))
# Out:
# The accuracy of NaiveBayes model: 95.32163742690058
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.97       116
#          1.0       0.96      0.89      0.92        55
#
#     accuracy                           0.95       171
#    macro avg       0.96      0.94      0.95       171
# weighted avg       0.95      0.95      0.95       171

# %% [markdown]
# PCA with Naive Bayes Model

# %%
pca_model=GaussianNB()
pca_model.fit(pc_train,y_train)
pca_prediction1=pca_model.predict(pc_test)
pca_accuracy1=accuracy_score(y_test,pca_prediction1)
print("The accuracy on PCA GaussianNB model:",pca_accuracy1*100)
# Out:
# The accuracy on PCA GaussianNB model: 86.54970760233918

# %% [markdown]
# Predict Classification

# %%
input_data=(17.99,10.38,122.8,1001,0.1184,0.2776,0.3001,0.1471,0.2419,0.07871,1.095,0.9053,8.589,153.4,0.006399,0.04904,0.05373,0.01587,0.03003,0.006193,25.38,17.33,184.6,2019,0.1622,0.6656,0.7119,0.2654,0.4601,0.1189)
input_data_as_numpy=np.asarray(input_data)
reshape=input_data_as_numpy.reshape(1,-1)
prediction=lr.predict(reshape)
print(prediction)
if(prediction[0]==0):
    print("The cancer is Malignant")
else:
    print("The cancer is Benign")
# Out:
# [1.]
# The cancer is Benign

# %% [markdown]
# BarPlot

# %%
fig=plt.figure(figsize=(10,5))
x={'KNN':94,'LogisticRegression':96,'SVM':95,'NaiveBayes':95}
percentage=list(x.keys())
values=list(x.values())
plt.bar(percentage,values,color='maroon',width=0.2)
plt.xlabel("Algorithms")
plt.ylabel("Percentage")
plt.title("Algorithm Comparison")
plt.show()

# %%
from tabulate import tabulate
print("                  Performance Comparison                  ")
table_data=[["Metrics","KNN","LogisticRegression","Naive Bayes","SVM"],
            ["Accuracy","94.7","95.9","95.3","95.3"],
            ["Precision","0.96","0.95","0.95","0.94"],
            ["Recall","0.97","0.99","0.98","0.99"],
            ["Principle Component Analysis","94.7","95.9","86.5","95.3"]]
print(tabulate(table_data,headers="firstrow",tablefmt="psql"))
# Out:
#                   Performance Comparison
# +------------------------------+-------+----------------------+---------------+-------+
# | Metrics                      |   KNN |   LogisticRegression |   Naive Bayes |   SVM |
# |------------------------------+-------+----------------------+---------------+-------|
# | Accuracy                     | 94.7  |                95.9  |         95.3  | 95.3  |
# | Precision                    |  0.96 |                 0.95 |          0.95 |  0.94 |
# | Recall                       |  0.97 |                 0.99 |          0.98 |  0.99 |
# | Principle Component Analysis | 94.7  |                95.9  |         86.5  | 95.3  |
# +------------------------------+-------+----------------------+---------------+-------+
